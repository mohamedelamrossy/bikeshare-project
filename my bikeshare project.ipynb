# %%
import time
import pandas as pd
import numpy as np

CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!\n')
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    while True:
        city = input("\n choose one of these three cities to explore : chicago, new york city or  washington:\n").lower()
        if city not in CITY_DATA:
            print(" \n Opps ! this input is not in the three cities, please input one of the three cities \n ")
        else :
            break
        
    # TO DO: get user input for month (all, january, february, ... , june)
    while True:
        month = input("\n chose one of this months : january,february,march,april,may,june or all to explore:\n " ).lower()
        months= [ 'january','february','march','april','may','june']
        if month not in months and month!= 'all':
            print("\n Opps !  this input is not in the six months,please input one of the six months ")
        else :
            break

    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    while True :
        day = input("\n choose one of these days : saturday,sunday,monday,tuesday,wednesday ,thursday ,friday or all to explore:\n ").lower()
        days= ['saturday','sunday','monday','tuesday','wednesday' ,'thursday','friday','all']
        if day not in days and day != 'all':
            print("\n  opps! this input is not in the seven days, please input one of the seven days ")
        else:
            break
                    
    print('-'*40)
    return city, month, day

def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """

    # creat a dataframe by the data file of the city
    df = pd.read_csv(CITY_DATA[city])

    # convert the Start Time column to datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])

    # extract month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.day_name()

    # filter by month if applicable
    if month != 'all':
        # use the index of the months list to get the corresponding int
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1

        # filter by month to create the new dataframe
        df = df[df['month'] == month]

    # filter by day of week if applicable
    if day != 'all':
        # filter by day of week to create the new dataframe
        df = df[df['day_of_week'] == day.title()]

    return df
def view_raw_data(df):
    
    """" this function is to display a number of raw data to the user if he want that"""
    #calculate user stats
    print('\nCalculating User Stats...\n')
    start_time = time.time()
    
    # chick the desire of the user about this mission
    print('\nhello :\nwe are happy to to this mission for you\n')
    desire = input('\nif you like to view 5 rows of the data :\nplease input yes for agree\nor no for not\n').lower()
    x= 0
    while True :
        if desire != 'yes'and desire != 'no':
            desire= input('\nplease input yes or no only to continue\n').lower()
        if desire == 'no':
            print('\nok no broplem you can continue now\n')
            break
        print(df.iloc[x:x+5])
        
        desire = input('\nif you like to view the next 5 rows of the data :\nplease input yes for agree\nor no for not\n').lower()
            
        x += 5
        print("\nThis took %s seconds." % (time.time() - start_time))
        print('-'*40)

def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    most_common_month = df['month'].mode()[0]
    print('\n the most common month is :\n ',format(most_common_month))


    # TO DO: display the most common day of week
    most_common_day_of_week = df['day_of_week'].mode()[0]
    print('\n the most common day of week is :\n ',format(most_common_day_of_week))


    # TO DO: display the most common start hour
    df['hours']=df['Start Time'].dt.hour
    most_common_hour = df['hours'].mode()[0]
    print('\n the most common start hour of the day is :\n',format(most_common_hour))


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)
    

def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    most_commonly_used_start_station = df['Start Station'].mode()[0]
    print('\n the most commonly used start station is :\n  ',format( most_commonly_used_start_station))
    
    # Display the most commonly used end station also
    the_most_commonly_used_end_station = df['End Station'].mode()[0]
    print('\n the most commonly used end station is:\n ',format(the_most_commonly_used_end_station))
    

    # TO DO: display most frequent combination of start station and end station trip
    df['most_common_trip'] = df['Start Station']+' to ' + df['End Station']
    print('\n the most common trip is :\n ',format(df['most_common_trip'].mode()[0]))
    

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    total_tarvel_time = df['Trip Duration'].sum()
    print('\n the total travel time equal  :\n ',format(total_tarvel_time),' in seconds \nand ' , total_tarvel_time/(60*60),' in hour')


    # TO DO: display mean travel time
    mean_travel_time = df['Trip Duration'].mean()
    print('\n the mean travel time equal  :\n ',format(mean_travel_time),'in seconds \nand ' ,mean_travel_time/(60*60),' in hour')
    
    


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def user_stats(df):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    counts_of_user_types = df['User Type'].value_counts()
    print(' \n the counts of users are :\n ', format(counts_of_user_types))
    
    # TO DO: Display counts of gender
    # note that : washington dataframe don`t has the the gender column
    if  'Gender' in df:
        counts_of_gender = df['Gender'].value_counts()
        print('\n the counts of gender are :\n',format(counts_of_gender))
        
    # TO DO: Display earliest, most recent, and most common year of birth
    # note that : washington dataframe don`t has the the birth year column
    if  'Birth Year' in df:
        #find earliest year of birth year column
        earliest_year = int(df['Birth Year'].min())
        print('\n the earliest year is :\n',format(earliest_year))
        #find most recent year of birth year column
        most_recent_year = int(df['Birth Year'].max())
        print('\n the most recent year is :\n',format(most_recent_year))
        #find most common year of birth of birth year column
        most_common_year_of_birth = int(df['Birth Year'].mode()[0])
        print('\n the most common year of birth is :\n',format(most_common_year_of_birth))
                                        

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)
        
        view_raw_data(df)
        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)
        

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
	main()
# Out:
# Hello! Let's explore some US bikeshare data!
#
#
#  choose one of these three cities to explore : chicago, new york city or  washington:
# chicago
#
#  chose one of this months : january,february,march,april,may,june or all to explore:
#  all
#
#  choose one of these days : saturday,sunday,monday,tuesday,wednesday ,thursday ,friday or all to explore:
#  all
# ----------------------------------------
#
# Calculating User Stats...
#
#
# hello :
# we are happy to to this mission for you
#
#
# if you like to view 5 rows of the data :
# please input yes for agree
# or no for not
# yes
#    Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1      955915 2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2        9031 2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3      304487 2017-03-06 13:49:38  2017-03-06 13:55:28            350
# ...
